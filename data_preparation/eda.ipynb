# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect('../data/extracted/paper_data.db')
papers = pd.read_sql_query("SELECT * FROM paper_data;", con)
con.close()

# %%
papers
# Out:
#                                                    title  \
# 0      Artificial neural network prediction of transp...
# 1      Light-assisted synthesis of Au/TiO2 nanopartic...
# 2      Competition and epibiosis by the sponge Pseudo...
# 3      Multilocus Sequence Typing and Virulence Poten...
# 4      Outcomes of a multidisciplinary transition cli...
# ...                                                  ...
# 17919  Nutrient deprivation-associated changes in gre...
# 17920  Amyloid-β aggregation inhibitors from Cleroden...
# 17921  Novel sulfonamidospirobifluorenes as fluoresce...
# 17922  Investigating the impact of critical factors o...
# 17923  Compact buds with biphasic differentiation and...
#
#                                              description  year   coverdate  \
# 0      Novel N-methyl-4-piperidinol (MPDL)-based solv...  2022  2022-08-01
# 1      A series of Au/TiO2 photocatalysts was synthes...  2022  2022-07-01
# 2      Competition for space on coral reefs is fierce...  2022  2022-01-01
# 3      Vibrio parahaemolyticus is a Gram-negative, fo...  2022  2022-06-01
# 4      Background: Emerging adults with type 1 diabet...  2022  2022-01-01
# ...                                                  ...   ...         ...
# 17919  The utilization of microalgae as a source of c...  2019  2019-06-01
# 17920  Clerodendrum inerme L. (Verbenaceae) is a medi...  2019  2019-05-01
# 17921  Novel spirobifluorene derivatives containing t...  2019  2019-01-01
# 17922  With the intensification of globalization and ...  2019  2019-11-01
# 17923  Immunophenotype of thyroglossal duct (TGD) cys...  2019  2019-05-01
#
#                                         publication_name citation_count  \
# 0                                         Energy Reports              4
# 1               International Journal of Hydrogen Energy             20
# 2                     Regional Studies in Marine Science              3
# 3                                  Microbiology Spectrum              1
# 4                               Pediatrics International              0
# ...                                                  ...            ...
# 17919                                       Marine Drugs             11
# 17920  Maejo International Journal of Science and Tec...              1
# 17921                                       RSC Advances              7
# 17922                       Sustainability (Switzerland)             13
# 17923                                    Virchows Archiv              2
#
#                                            subject_areas  \
# 0                                           Energy (all)
# 1      Renewable Energy, Sustainability and the Envir...
# 2      Ecology, Evolution, Behavior and Systematics+A...
# 3      Physiology+Ecology+Immunology and Microbiology...
# 4              Pediatrics, Perinatology and Child Health
# ...                                                  ...
# 17919                                     Drug Discovery
# 17920                                  Multidisciplinary
# 17921         Chemistry (all)+Chemical Engineering (all)
# 17922  Geography, Planning and Development+Renewable ...
# 17923  Pathology and Forensic Medicine+Molecular Biol...
#
#                                             author_names  \
# 0      Nimmanterdwong P.+Janthboon P.+Tontiwachwuthik...
# 1      Kunthakudee N.+Puangpetch T.+Ramakul P.+Seriva...
# 2      Allchurch A.+Mehrotra R.+Carmody H.+Monchanin ...
# 3      Muangnapoh C.+Tamboon E.+Supha N.+Toyting J.+C...
# 4      Wongyai W.+Boonchaya-anant P.+Laichuthai N.+Ar...
# ...                                                  ...
# 17919  Rauytanapanit M.+Janchot K.+Kusolkumbot P.+Sir...
# 17920  Kor-Arnan T.+Rojpitikul T.+Phuwapraisirisan P....
# 17921  Silpcharu K.+Sukwattanasinitt M.+Rashatasakhon P.
# 17922                Ma Y.+Ruangkanjanases A.+Chen S.-C.
# 17923                             Keelawat S.+Bychkov A.
#
#                                             affiliations  \
# 0      Chulalongkorn University+Clean Energy Technolo...
# 1      Chulalongkorn University+Silpakorn University+...
# 2      The University of Western Australia+Chulalongk...
# 3      Mahidol University, Faculty of Dentistry+Chula...
# 4      Faculty of Medicine, Chulalongkorn University+...
# ...                                                  ...
# 17919  Chulalongkorn University+Thailand Institute of...
# 17920                           Chulalongkorn University
# 17921                           Chulalongkorn University
# 17922  Chulalongkorn Business School+National Kaohsiu...
# 17923  Graduate School of Biomedical Sciences+Kameda ...
#
#                                             countries       file_name  \
# 0                               Thailand+Canada+China  202201532.json
# 1                                            Thailand  202201728.json
# 2      Australia+Thailand+Canada+United States+France  202204089.json
# 3                                      Thailand+Japan  202201904.json
# 4                                            Thailand  202203287.json
# ...                                               ...             ...
# 17919                                        Thailand  201901331.json
# 17920                                        Thailand  201901475.json
# 17921                                        Thailand  201902872.json
# 17922                           Thailand+Taiwan+China  201900401.json
# 17923                                  Japan+Thailand  201901535.json
#
#                                   doi
# 0          10.1016/j.egyr.2022.02.117
# 1      10.1016/j.ijhydene.2022.05.150
# 2          10.1016/j.rsma.2021.102131
# 3           10.1128/spectrum.00886-22
# 4                   10.1111/ped.15356
# ...                               ...
# 17919              10.3390/md17060328
# 17920
# 17921              10.1039/C9RA00004F
# 17922              10.3390/su11215914
# 17923      10.1007/s00428-019-02536-6
#
# [17924 rows x 12 columns]

# %%
str_cols = papers.select_dtypes(include=['object']).columns

for col in str_cols:
    papers[col] = papers[col].replace('', np.nan)

papers.loc[papers.doi.isna(), ['title', 'file_name']].iloc[0, 0]
# Out:
# 'Pancyclicity of Generalized Prisms over Specific Types of Skirted Graphs'

# %%
df = pd.read_csv('../data/processed_data/scopus_data_doi.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df = pd.read_csv('scopus_data_fixed.csv')
#
# File ~/Projects/DS-Project-2/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Projects/DS-Project-2/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Projects/DS-Project-2/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Projects/DS-Project-2/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Projects/DS-Project-2/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scopus_data_fixed.csv'

# %%
df[df.doi.isna() | df.doi.eq('')]
# Out:
#                                                    title  \
# 4572   Antioxidant activities of local oregano and sw...
# 6274   Caring detachment in buddhism and implications...
# 7763   The optimal divalent cations and storage tempe...
# 11082  Taxonomic Progress and Diversity of Ichneumono...
# 11094  Conversion of cassava rhizome to biocrude oil ...
# 12799  Diversity and Distribution of Jellyfish Polyps...
# 14916  Association between the appropriate antimicrob...
# 15268                                                NaN
# 16528  Identification of risk of cyberbullying from s...
#
#                                              description  year   coverdate  \
# 4572   Total phenolic contents (TPC) and 2,2-diphenyl...  2018  2018-10-01
# 6274                                                 NaN  2020  2020-01-15
# 7763   The aim of this study was to investigate the e...  2020  2020-03-01
# 11082  Taxonomic studies on parasitoid wasps in the s...  2021  2021-01-01
# 11094  Hydrothermal liquefaction (HTL) was applied to...  2021  2021-09-01
# 12799  Jellyfish polyps can be difficult to identify ...  2023  2023-01-01
# 14916  Sepsis is the leading cause of death in hospit...  2019  2019-01-01
# 15268  The current study is interested in knowing the...  2019  2019-01-01
# 16528  Social networks have revolutionalized how peop...  2019  2019-01-01
#
#                                         publication_name  citation_count  \
# 4572                 International Food Research Journal             1.0
# 6274        Explorations in Women, Rights, and Religions             0.0
# 7763                 Thai Journal of Veterinary Medicine             0.0
# 11082                           Tropical Natural History             0.0
# 11094                       International Energy Journal             2.0
# 12799                           Tropical Natural History             0.0
# 14916            Thai Journal of Pharmaceutical Sciences             0.0
# 15268  International Journal of Innovation, Creativit...             1.0
# 16528  Lecture Notes in Engineering and Computer Science             4.0
#
#                                            subject_areas  \
# 4572                                        Food Science
# 6274     Arts and Humanities (all)+Social Sciences (all)
# 7763                                    Veterinary (all)
# 11082  Ecology, Evolution, Behavior and Systematics+E...
# 11094                                       Energy (all)
# 12799  Ecology, Evolution, Behavior and Systematics+E...
# 14916                Pharmacology+Pharmaceutical Science
# 15268      Education+Arts and Humanities (miscellaneous)
# 16528                   Computer Science (miscellaneous)
#
#                                             author_names  \
# 4572   Chinprahast N.+Saengbamroong P.+Wongtreenetkul...
# 6274                                      Satha-Anand S.
# 7763   Thiangthientham P.+Suwimonteerabutr J.+Tharasa...
# 11082          Songvorawit N.+Quicke D.L.J.+Butcher B.A.
# 11094  Chukaew P.+Nakason K.+Kuboon S.+Kraithong W.+P...
# 12799       Punnarak P.+Sopon A.+Panichpol A.+Bunpent T.
# 14916  Lertvipapath P.+Puttilerpong C.+Werarak P.+Cha...
# 15268  Wajeetongratana P.+Joemsittiprasert W.+Jermsit...
# 16528           Semangern T.+Chaisitsak W.+Senivongse T.
#
#                                             affiliations  \
# 4572                            Chulalongkorn University
# 6274                            Chulalongkorn University
# 7763    Chulalongkorn University+Mahasarakham University
# 11082                           Chulalongkorn University
# 11094  Chulalongkorn University+Thailand National Nan...
# 12799  Chulalongkorn University+Marine ecology and ut...
# 14916  Faculty of Medicine Siriraj Hospital, Mahidol ...
# 15268  Suan Sunandha Rajabhat University+Chulalongkor...
# 16528                           Chulalongkorn University
#
#                     countries       file_name  doi
# 4572                 Thailand  201800475.json  NaN
# 6274                 Thailand  202002448.json  NaN
# 7763                 Thailand  202002135.json  NaN
# 11082                Thailand  202103524.json  NaN
# 11094                Thailand  202101115.json  NaN
# 12799                Thailand  202302197.json  NaN
# 14916                Thailand  201902689.json  NaN
# 15268  Thailand+United States  201902385.json  NaN
# 16528                Thailand  201902279.json  NaN
